# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\python\python setup\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\python\python setup\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\python\python setup\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in d:\python\python setup\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in d:\python\python setup\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\python\python setup\lib\site-packages (3.6.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in d:\python\python setup\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in d:\python\python setup\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python\python setup\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python\python setup\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in d:\python\python setup\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in d:\python\python setup\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\python\python setup\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python\python setup\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python\python setup\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\python\python setup\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\python\python setup\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in d:\python\python setup\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in d:\python\python setup\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in d:\python\python setup\lib\site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python\python setup\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\python\python setup\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in d:\python\python setup\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('gld_price_data.csv')

# %%
df.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
df.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
df.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %% [markdown]
# # Correlation

# %%
cor = df.corr()
cor
# Out:
# C:\Users\Prabakaran\AppData\Local\Temp\ipykernel_10504\3057578215.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = df.corr()
#               SPX       GLD       USO       SLV   EUR/USD
# SPX      1.000000  0.049345 -0.591573 -0.274055 -0.672017
# GLD      0.049345  1.000000 -0.186360  0.866632 -0.024375
# USO     -0.591573 -0.186360  1.000000  0.167547  0.829317
# SLV     -0.274055  0.866632  0.167547  1.000000  0.321631
# EUR/USD -0.672017 -0.024375  0.829317  0.321631  1.000000

# %%
plt.figure(figsize = (8,8))
sns.heatmap(cor, cbar = True, square = True, fmt = '.1f', annot = True, annot_kws = {'size':8}, cmap = 'Greens')
# Out:
# <AxesSubplot: >

# %%
cor['GLD']
# Out:
# SPX        0.049345
# GLD        1.000000
# USO       -0.186360
# SLV        0.866632
# EUR/USD   -0.024375
# Name: GLD, dtype: float64

# %%
sns.distplot(df['GLD'], color = "blue")
# Out:
# C:\Users\Prabakaran\AppData\Local\Temp\ipykernel_10504\2141170081.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['GLD'], color = "blue")
# <AxesSubplot: xlabel='GLD', ylabel='Density'>

# %%
X = df.drop(['GLD', 'Date'], axis = 1)
Y = df['GLD']

# %%
X1 = df['SLV']

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\python\python setup\lib\site-packages (1.2.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.17.3 in d:\python\python setup\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in d:\python\python setup\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in d:\python\python setup\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\python\python setup\lib\site-packages (from scikit-learn) (3.1.0)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
y = Y.values.reshape(-1,1)
x = X1.values.reshape(-1,1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_, reg.coef_
# Out:
# (array([66.67265575]), array([[2.78939095]]))

# %%
Y_pred = reg.predict(X_test)

# %%
plt.scatter(X_test,Y_test, label = "Data points", color = "green")
plt.plot(X_test, Y_pred,color='red') 
plt.xlabel("Silver Price")
plt.ylabel("Gold Price")
plt.title("Linear Regression")
plt.show
plt.savefig("LR.png")

# %%
r2 = r2_score(Y_test,Y_pred)
print("R squared error : ", r2)
# Out:
# R squared error :  0.787055394163785

# %% [markdown]
# # Multilinear regression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_, reg.coef_
# Out:
# (72.12619785544354,
#  array([ 6.41059545e-03, -2.43351009e-01,  3.14181740e+00, -1.20044898e+01]))

# %%
Y_pred = reg.predict(X_test)

# %%
plt.scatter(Y_test,Y_pred, label = "Data points", color = "blue")
plt.title("Multilinear Regression")
plt.xlabel("Actual Value")
plt.ylabel("Predicted Value")
plt.savefig("MLR.png")

# %%
r2 = r2_score(Y_test,Y_pred)
print("R squared error : ", r2)
plt.savefig("MLR.png")
# Out:
# R squared error :  0.8990852171300425

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor(random_state = 0)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='blue', label = 'Actual Value')
plt.plot(y_pred, color='green', label='Predicted Value')
plt.title('Decision Tree Regression')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()
plt.savefig("DT.png")

# %%
error_score = r2_score(Y_test, y_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9854190298916252

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
regressor = RandomForestRegressor(n_estimators=100)

# %%
regressor.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
test_data_prediction = regressor.predict(X_test)

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='blue', label = 'Actual Value')
plt.plot(test_data_prediction, color='green', label='Predicted Value')
plt.title('Random Forest Regression')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()
plt.savefig("RF.png")

# %%
error_score = r2_score(Y_test, test_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9892484657457359
